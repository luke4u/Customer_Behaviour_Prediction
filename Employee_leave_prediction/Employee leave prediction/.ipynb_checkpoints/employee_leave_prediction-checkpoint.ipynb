# %% [markdown]
# ### 1. Problem statement:
#   1. HR Team collected extensive data on employees and asked to develop a model to predict which employee is likely to quit.
#   2. dataset includes:
#     - jobinvolvement
#     - eduation
#     - jobsatisfaction
#     - performancerating
#     - relationshipsatisfaction
#     - worklifebalance
#     - etc.

# %% [markdown]
# ### 2. Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.ensemble import RandomForestClassifier
from imblearn.over_sampling import SMOTE
from keras.models import Sequential
from keras.layers import Dense, Dropout

# %% [markdown]
# ### 3. EDA

# %%
employee_df = pd.read_csv('Human_Resources.csv')

# %%
employee_df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# ### 3.1 Distribution review

# %%
employee_df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
employee_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
# Age                         1470 non-null int64
# Attrition                   1470 non-null object
# BusinessTravel              1470 non-null object
# DailyRate                   1470 non-null int64
# Department                  1470 non-null object
# DistanceFromHome            1470 non-null int64
# Education                   1470 non-null int64
# EducationField              1470 non-null object
# EmployeeCount               1470 non-null int64
# EmployeeNumber              1470 non-null int64
# EnvironmentSatisfaction     1470 non-null int64
# Gender                      1470 non-null object
# HourlyRate                  1470 non-null int64
# JobInvolvement              1470 non-null int64
# JobLevel                    1470 non-null int64
# JobRole                     1470 non-null object
# JobSatisfaction             1470 non-null int64
# ...

# %% [markdown]
# ### 3.2 Data quality check

# %%
employee_df.isna().any()
# Out:
# Age                         False
# Attrition                   False
# BusinessTravel              False
# DailyRate                   False
# Department                  False
# DistanceFromHome            False
# Education                   False
# EducationField              False
# EmployeeCount               False
# EmployeeNumber              False
# EnvironmentSatisfaction     False
# Gender                      False
# HourlyRate                  False
# JobInvolvement              False
# JobLevel                    False
# JobRole                     False
# JobSatisfaction             False
# MaritalStatus               False
# MonthlyIncome               False
# MonthlyRate                 False
# NumCompaniesWorked          False
# Over18                      False
# OverTime                    False
# PercentSalaryHike           False
# PerformanceRating           False
# RelationshipSatisfaction    False
# StandardHours               False
# ...

# %%
employee_df.isnull().any()
# Out:
# Age                         False
# Attrition                   False
# BusinessTravel              False
# DailyRate                   False
# Department                  False
# DistanceFromHome            False
# Education                   False
# EducationField              False
# EmployeeCount               False
# EmployeeNumber              False
# EnvironmentSatisfaction     False
# Gender                      False
# HourlyRate                  False
# JobInvolvement              False
# JobLevel                    False
# JobRole                     False
# JobSatisfaction             False
# MaritalStatus               False
# MonthlyIncome               False
# MonthlyRate                 False
# NumCompaniesWorked          False
# Over18                      False
# OverTime                    False
# PercentSalaryHike           False
# PerformanceRating           False
# RelationshipSatisfaction    False
# StandardHours               False
# ...

# %% [markdown]
# #### no missing values

# %%
sns.heatmap(employee_df.isnull(), yticklabels = False, cbar = False, cmap = 'Blues')

# %% [markdown]
# ### 3.3 Categorical to Numerical conversion

# %%
employee_df['Attrition'] = employee_df['Attrition'].apply(lambda x: 1 if x == 'Yes' else 0)
employee_df['OverTime'] = employee_df['OverTime'].apply(lambda x: 1 if x == 'Yes' else 0)
employee_df['Over18'] = employee_df['Over18'].apply(lambda x: 1 if x == 'Y' else 0)

# %%
employee_df.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# ### 3.4 Data Distribution via Hist

# %%
employee_df.hist(bins = 30, figsize= (15, 15), color = 'r')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001BC79DC9C88>,
# ...
#       dtype=object)

# %% [markdown]
# ### 3.5 Drop meaningless columns

# %%
employee_df.drop(['EmployeeCount', 'EmployeeNumber', 'Over18', 'StandardHours'], axis = 1, inplace = True)

# %% [markdown]
# ### 3.6 Correlation between features

# %%
correlations = employee_df.corr()
plt.subplots(figsize = (20, 20))
sns.heatmap(correlations, annot = True)

# %% [markdown]
# #### employees leave and stay count plot at different ages

# %%
left_df = employee_df[ employee_df['Attrition'] == 1 ]
stayed_df = employee_df[ employee_df['Attrition'] == 0 ]

# %%
print('total employees: ', employee_df.shape[0])
print('left employees: ', left_df.shape[0], left_df.shape[0]/employee_df.shape[0] *100, '%')
print('stay employees: ', stayed_df.shape[0], stayed_df.shape[0]/employee_df.shape[0] *100, '%')
# Out:
# total employees:  1470
# left employees:  237 16.122448979591837 %
# stay employees:  1233 83.87755102040816 %

# %%
plt.figure(figsize = (25, 10), dpi = 300)
sns.countplot(x = 'Age', hue = 'Attrition', data = employee_df )

# %% [markdown]
# #### employees leave and stay count plot at different JobRoles, MartialStatus, JobInvolvement, JobLevel

# %%
plt.figure(figsize = (20, 10))
plt.subplot(211)
sns.countplot(x = 'JobRole', hue = 'Attrition', data = employee_df)

# %% [markdown]
# - kde (kernel density estimate) is for visualizing the probability density function of a continue variable
# - kde describes the probability density at different values

# %% [markdown]
# #### employees with more than 10 miles from home tend to leave than stay

# %%
plt.figure(figsize = (12, 7))
sns.kdeplot(left_df['DistanceFromHome'], label = 'Employee left', shade = True, color = 'r', )

sns.kdeplot(stayed_df['DistanceFromHome'], label = 'Employee stay', shade = True, color = 'b')

plt.xlabel('Distance from home')
# Out:
# Text(0.5, 0, 'Distance from home')

# %% [markdown]
# #### employees with more than 5 years tend to stay more than leave

# %%
plt.figure(figsize = (12, 7))
sns.kdeplot(left_df['YearsWithCurrManager'], label = 'Employee left', shade = True, color = 'r')

sns.kdeplot(stayed_df['YearsWithCurrManager'], label = 'Employee stay', shade = True, color = 'b')

plt.xlabel('Years With CurrManager')
# Out:
# Text(0.5, 0, 'Years With CurrManager')

# %% [markdown]
# #### employees tend to stay with more than about 7 years

# %%
plt.figure(figsize = (12, 7))
sns.kdeplot(left_df['TotalWorkingYears'], label = 'Employee left', shade = True, color = 'r')

sns.kdeplot(stayed_df['TotalWorkingYears'], label = 'Employee stay', shade = True, color = 'b')

plt.xlabel('Total Working Years')
# Out:
# Text(0.5, 0, 'Total Working Years')

# %% [markdown]
# #### compare monthly income for different gender

# %%
sns.boxplot( x = 'MonthlyIncome', y = 'Gender', data = employee_df)

# %% [markdown]
# #### compare different income for different roles: Sales representative

# %%
plt.figure(figsize= (10, 10))
sns.boxplot( x = 'MonthlyIncome', y = 'JobRole', data = employee_df)

# %% [markdown]
# ### 4. Data processing

# %%
employee_df.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  ...  PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# ...

# %% [markdown]
# ### 4.1 Separate numerical and categorical dataset

# %%
X_cat = employee_df[['BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus']]

# %%
X_cat.head()
# Out:
#       BusinessTravel              Department EducationField  Gender  \
# 0      Travel_Rarely                   Sales  Life Sciences  Female
# 1  Travel_Frequently  Research & Development  Life Sciences    Male
# 2      Travel_Rarely  Research & Development          Other    Male
# 3  Travel_Frequently  Research & Development  Life Sciences  Female
# 4      Travel_Rarely  Research & Development        Medical    Male
#
#                  JobRole MaritalStatus
# 0        Sales Executive        Single
# 1     Research Scientist       Married
# 2  Laboratory Technician        Single
# 3     Research Scientist       Married
# 4  Laboratory Technician       Married

# %% [markdown]
# ### 4.2 Onehot encoding

# %%
# onehotencoder = OneHotEncoder()
# X_cat = onehotencoder.fit_transform(X_cat).toarray()
X_cat = pd.get_dummies(X_cat)

# %%
X_cat
# Out:
#       BusinessTravel_Non-Travel  BusinessTravel_Travel_Frequently  \
# 0                             0                                 0
# 1                             0                                 1
# 2                             0                                 0
# 3                             0                                 1
# 4                             0                                 0
# 5                             0                                 1
# 6                             0                                 0
# 7                             0                                 0
# 8                             0                                 1
# 9                             0                                 0
# 10                            0                                 0
# 11                            0                                 0
# 12                            0                                 0
# ...

# %%
X_cat.head()
# Out:
#    BusinessTravel_Non-Travel  BusinessTravel_Travel_Frequently  \
# 0                          0                                 0
# 1                          0                                 1
# 2                          0                                 0
# 3                          0                                 1
# 4                          0                                 0
#
#    BusinessTravel_Travel_Rarely  Department_Human Resources  \
# 0                             1                           0
# 1                             0                           0
# 2                             1                           0
# 3                             0                           0
# 4                             1                           0
#
#    Department_Research & Development  Department_Sales  \
# 0                                  0                 1
# 1                                  1                 0
# ...

# %%
X_numerical = employee_df[['Age', 'DailyRate', 'DistanceFromHome','Education', 
                           'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement',
                           'JobLevel','JobSatisfaction','MonthlyIncome','MonthlyRate',
                           'NumCompaniesWorked','OverTime','PercentSalaryHike', 'PerformanceRating',
                           'RelationshipSatisfaction','StockOptionLevel',	'TotalWorkingYears',
                           'TrainingTimesLastYear', 'WorkLifeBalance','YearsAtCompany','YearsInCurrentRole', 
                           'YearsSinceLastPromotion','YearsWithCurrManager']]

# %%
X_all = pd.concat([X_cat, X_numerical], axis = 1)

# %%
X_all
# Out:
#       BusinessTravel_Non-Travel  BusinessTravel_Travel_Frequently  \
# 0                             0                                 0
# 1                             0                                 1
# 2                             0                                 0
# 3                             0                                 1
# 4                             0                                 0
# 5                             0                                 1
# 6                             0                                 0
# 7                             0                                 0
# 8                             0                                 1
# 9                             0                                 0
# 10                            0                                 0
# 11                            0                                 0
# 12                            0                                 0
# ...

# %%
y = employee_df['Attrition']

# %% [markdown]
# ### 4.3 Scalling dataset

# %%
scaler = MinMaxScaler()
X = scaler.fit_transform(X_all)

# %%
# 1/0

# %% [markdown]
# ### 4.4 Train and test split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# %% [markdown]
# ### 4.5 SMOTE oversampling

# %%
oversampler = SMOTE(random_state=0)
X_smote_train, y_smote_train = oversampler.fit_sample(X_train,y_train)

# %% [markdown]
# ### 5. Logistic regression model

# %%
model = LogisticRegression()
model.fit(X_smote_train, y_smote_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# #### by default, metrics is for class 1: leave

# %%
print('Logistic regression model Accuracy {}%'.format(100 * accuracy_score(y_pred, y_test)))
print('Logistic regression model Precision {}%'.format(100 * precision_score(y_pred, y_test)))
print('Logistic regression model Recall {}%'.format(100 * recall_score(y_pred, y_test)))
print('Logistic regression model F1 {}%'.format(100 * f1_score(y_pred, y_test)))
# Out:
# Logistic regression model Accuracy 74.72826086956522%
# Logistic regression model Precision 69.35483870967742%
# Logistic regression model Recall 36.75213675213676%
# Logistic regression model F1 48.04469273743017%

# %%
cm = confusion_matrix(y_pred, y_test)
sns.heatmap(cm, annot= True)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.76      0.83       306
#            1       0.37      0.69      0.48        62
#
#     accuracy                           0.75       368
#    macro avg       0.65      0.73      0.66       368
# weighted avg       0.83      0.75      0.77       368

# %% [markdown]
# ### 6. Random Forest model

# %%
model = RandomForestClassifier()

model.fit(X_smote_train, y_smote_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = model.predict(X_test)

# %%
print('RF model Accuracy {}%'.format(100 * accuracy_score(y_pred, y_test)))
print('RF model Precision {}%'.format(100 * precision_score(y_pred, y_test)))
print('RF model Recall {}%'.format(100 * recall_score(y_pred, y_test)))
print('RF model F1 {}%'.format(100 * f1_score(y_pred, y_test)))
# Out:
# RF model Accuracy 84.23913043478261%
# RF model Precision 32.25806451612903%
# RF model Recall 55.55555555555556%
# RF model F1 40.816326530612244%

# %%
cm = confusion_matrix(y_pred, y_test)
sns.heatmap(cm, annot= True)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.95      0.91       306
#            1       0.56      0.32      0.41        62
#
#     accuracy                           0.84       368
#    macro avg       0.71      0.64      0.66       368
# weighted avg       0.82      0.84      0.82       368

# %% [markdown]
# ### 7. ANN

# %%
model = Sequential()
model.add(Dense(units = 50, activation = 'relu', input_shape = (50, )))
model.add(Dense(units = 500, activation = 'relu'))
model.add(Dropout(0.3))
model.add(Dense(units = 500, activation = 'relu'))
model.add(Dropout(0.3))
model.add(Dense(units = 50, activation = 'relu'))
model.add(Dense(units = 1, activation = 'sigmoid'))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_11 (Dense)             (None, 50)                2550
# _________________________________________________________________
# dense_12 (Dense)             (None, 500)               25500
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 500)               250500
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 50)                25050
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 51
# ...
# Total params: 303,651
# ...

# %%
model.compile(optimizer='adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
epochs_hist = model.fit(X_smote_train, y_smote_train, epochs = 50, batch_size = 50)
# Out:
# Epoch 1/50
# 1854/1854 [==============================] - 1s 477us/step - loss: 0.5902 - acc: 0.6807
# Epoch 2/50
# 1854/1854 [==============================] - 0s 221us/step - loss: 0.4422 - acc: 0.7869
# Epoch 3/50
# 1854/1854 [==============================] - 0s 224us/step - loss: 0.3776 - acc: 0.8350
# Epoch 4/50
# 1854/1854 [==============================] - 0s 238us/step - loss: 0.3209 - acc: 0.8657
# Epoch 5/50
# 1854/1854 [==============================] - 0s 220us/step - loss: 0.2769 - acc: 0.8862
# Epoch 6/50
# 1854/1854 [==============================] - 0s 224us/step - loss: 0.2244 - acc: 0.9153
# Epoch 7/50
# 1854/1854 [==============================] - 0s 221us/step - loss: 0.2192 - acc: 0.9169
# Epoch 8/50
# 1854/1854 [==============================] - 0s 221us/step - loss: 0.1514 - acc: 0.9412
# Epoch 9/50
# 1854/1854 [==============================] - 0s 226us/step - loss: 0.1140 - acc: 0.9579
# Epoch 10/50
# ...

# %%
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5)

# %%
plt.plot(epochs_hist.history['loss'])
plt.title('Model Loss Progress During Training')
plt.xlabel('Epoch')
plt.ylabel('Training Loss')
plt.legend(['Training Loss'])

# %%
epochs_hist.history.keys()
# Out:
# dict_keys(['loss', 'acc'])

# %%
plt.plot(epochs_hist.history['acc'])
plt.title('Model Accuracy Progress During Training')
plt.xlabel('Epoch')
plt.ylabel('Training accuracy')
plt.legend(['Training accuracy'])

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot = True)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.87      0.88       306
#            1       0.40      0.42      0.41        62
#
#     accuracy                           0.80       368
#    macro avg       0.64      0.65      0.64       368
# weighted avg       0.80      0.80      0.80       368
